# %% [markdown]
# # Business Problem
# ### The problem in this capstone project is that I am a gym owner and would like to expand my gym locations. I am looking to move into North York, Canada and need to know the neighborhoods that need more exersice venue options in their communities. Therefore I will need to leverage the Foursquare API and clustering to find which locations are depreived of physical activity when is comes to their venues.

# %% [markdown]
# # Data
#
# ### In order solve this problem, I will gather data scrapped from Wikipedia to get information on the different neighborhoods withing North York, Canada and their appropriate postal codes. I will then gather the coordinates of each neighborhood using the  provied csv file and sync them based on their postal codes. The Foursqaure API will be utilized to gather
# Foursquare API in order to get the venue data.
